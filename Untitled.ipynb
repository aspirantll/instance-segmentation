# %%
import os
print(os.getcwd())
print(os.listdir(os.getcwd()))
# Out:
# /home/ma-user/work
# ['utils', 'alphashape', 'configs', 'Untitled.ipynb', 'evaluate.py', 'pip-requirements.txt', 'preprocess_cityscapes.py', 'Shapely-1.7.0-cp36-cp36m-manylinux1_x86_64.whl', 'sync.py', 'test.py', 'train.py', 'data', 'models', 'terminaltables', 'test']

# %%
print(os.listdir('./test'))
# Out:
# ['opt.txt', 'logs', 'frankfurt_000000_000294_leftImg8bit.png_center2000.png', 'frankfurt_000000_000294_leftImg8bit.png_box.png', 'mask_boundfrankfurt_000000_000294_leftImg8bit.png', 'frankfurt_000000_000294_leftImg8bit.png_bound10000.png', 'frankfurt_000000_000294_leftImg8bit.png_candid.png', 'frankfurt_000000_000294_leftImg8bit.png', 'frankfurt_000000_000576_leftImg8bit.png_center2000.png', 'frankfurt_000000_000576_leftImg8bit.png_box.png', 'mask_boundfrankfurt_000000_000576_leftImg8bit.png', 'frankfurt_000000_000576_leftImg8bit.png_bound10000.png', 'frankfurt_000000_000576_leftImg8bit.png_candid.png', 'frankfurt_000000_000576_leftImg8bit.png', 'frankfurt_000000_001016_leftImg8bit.png_center2000.png', 'frankfurt_000000_001016_leftImg8bit.png_box.png', 'mask_boundfrankfurt_000000_001016_leftImg8bit.png', 'frankfurt_000000_001016_leftImg8bit.png_bound10000.png', 'frankfurt_000000_001016_leftImg8bit.png_candid.png', 'frankfurt_000000_001016_leftImg8bit.png', 'frankfurt_000000_001236_le
# ...

# %%
# !pip install -r pip-requirements.txt
# Out:
# ...
# Processing ./Shapely-1.7.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#     100% |████████████████████████████████| 440kB 99.3MB/s eta 0:00:01████████▉                | 215kB 84.9MB/s eta 0:00:01
# ...
# You are using pip version 9.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !python test.py
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2
# loading the arguments...
# test dir: s3://ll-coco/datasets/cityscapes/leftImg8bit/val
# save dir: ./test
# [2020-04-28 23:47:51] start to test...
# [2020-04-28 23:47:55] loaded the weights:s3://ll-coco/dla/dla_weights_00000050.pth
# [2020-04-28 23:48:02] in frankfurt_000000_000294_leftImg8bit.png detected 9 objs
# [2020-04-28 23:48:03] detected result saved in ./test/frankfurt_000000_000294_leftImg8bit.png
# [2020-04-28 23:48:06] in frankfurt_000000_000576_leftImg8bit.png detected 16 objs
# [2020-04-28 23:48:06] detected result saved in ./test/frankfurt_000000_000576_leftImg8bit.png
# [2020-04-28 23:48:09] in frankfurt_000000_001016_leftImg8bit.png detected 6 objs
# [2020-04-28 23:48:09] detected result saved in ./test/frankfurt_000000_001016_leftImg8bit.png
# [2020-04-28 23:48:13] in frankfurt_000000_001236_leftImg8bit.png detected 28 objs
# ...

# %%
import moxing as mox
mox.file.copy_parallel('./test', 's3://ll-coco/dla/test/')
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2

# %%
# !python evaluate.py
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2
# rm: cannot remove '/home/work/anaconda3/lib/libmkldnn.so': No such file or directory
# rm: cannot remove '/home/work/anaconda3/lib/libmkldnn.so.0': No such file or directory
# loading the arguments...
# eval dir: s3://ll-coco/datasets/cityscapes
# save dir: s3://ll-coco/dla/eval
# INFO:root:Listing OBS: 1000
# INFO:root:Listing OBS: 1000
# dataset size: 2975
# start to evaluate...
# [2020-04-30 16:03:49] loaded the weights:s3://ll-coco/dla/dla_weights_00000050.pth
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
